# %% [markdown]
# # Regression Web Scraping

# %%
import requests

# %%
url = 'https://www.zillow.com/robots.txt'
response  = requests.get(url)
print(response.text)
# Out:
# # Access to and use of Zillow.com is governed by our Terms of Use. See http://www.zillow.com/corp/Terms.htm
#
# User-agent: *
# Disallow: /?url=
# Disallow: /*_rect
# Disallow: /*_rect/
# Disallow: /*_rid
# Disallow: /*_sort/
# Disallow: /*.sdirect
# Disallow: /*1_fs/
# Disallow: /*3ab9b0d/
# Disallow: /*3bec89b
# Disallow: /*/_type/
# Disallow: /*/0-0_beds/
# Disallow: /*/admin-ajax.php
# Disallow: /*/apartments-are_att/
# Disallow: /*/apartments-madden_att/
# Disallow: /*/apartments-offers_att/
# Disallow: /*/apartments-rent_att/
# Disallow: /*cbpartner=
# Disallow: /*/CountyAssessorPage.htm?*
# Disallow: /*/duplex-apartments_att/
# Disallow: /*/floor-map-annotator/*
# Disallow: /*/foreclosure--
# Disallow: */foreclosed/*
# Disallow: /*/GetResults.htm*
# Disallow: /*/house_type/
# Disallow: /*/house,apartment_duplex_type/
# Disallow: /*/house,mobile_type/
# Disallow: /*/house,mobile,land_type/
# Disallow: /*/house,mobile,townhouse_type/
# Disallow: /*/loft-apartments_att/
# Disallow: /*/mostrecentchange_sort/
# Disallow: /*/node_modules/.bin/
# Disallow: /*/plus/
# Disallow: /*/rent-house_att/
# Disallow: /*/rino-_att/
# Disallow: /*/qc/
# Disallow: /*-qc/
# Disallow: /*/townhome_att/
# Disallow: /*/u1_sch/
# Disallow: /*/z/internet-tv-deals-saver/?z*
# Disallow: /*/z/internet-tv-deals-speed/?z*
# Disallow: /*RentalConfirmedClaim
# Disallow: /*?searchQueryState=*
# Disallow: /ads/
# Disallow: /advice-thread/
# Disallow: /advicepages/
# Disallow: /aerial/
# Disallow: /advice/
# Disallow: /agent-websites/
# Disallow: /ajax/homedetail/CompareWithPublicFactsData.htm
# Disallow: /ajax/homedetail/HomeValueChartData.htm
# Disallow: /ajax/nav/UserNavAsync.htm?pageframe=true
# Disallow: /ajax/rentals/ClaimedRentalProperties.htm?actionType=claims
# Disallow: /ajax/ownerview/PerformSellerLeadContact.htm
# Disallow: /ajax/ownerview/SellerLeadData.htm
# Disallow: /app?
# Disallow: /b/*/rental-manager/resources/
# Disallow: /b/*bed*/
# Disallow: /b/*month*/
# Disallow: /b/*!*/
# Disallow: /b/*(*/
# Disallow: /b/*&*/
# Disallow: /b/*/*_ll/
# Disallow: /bal/impression/
# Disallow: /bal/impression/RecordImpression.htm?
# Disallow: /browse/homes/all/
# Disallow: /captcha/
# Disallow: /careers/apply/
# Disallow: /careers/jobs/
# Disallow: /claiming/
# Disallow: /claiming/ClaimProperty.htm?
# Disallow: /community/error-subdivision-name-unavailable/
# Disallow: /contact/
# Disallow: /corp/Privacy.htm
# Disallow: /corp/Terms.htm
# Disallow: /CountyAssessorPage.htm
# Disallow: /del/
# Disallow: /discovery/
# Disallow: /editing/
# Disallow: /email/EnrollmentUnsubscribe.htm
# Disallow: /email/SubscriptionTypeUnsubscribe.htm
# Disallow: /email/Unsubscribe.htm
# Disallow: /for-sale-by-owner/?zpid=
# Disallow: /home-improvement-dueling-digs/
# Disallow: /homedetail/AuthRequired.htm
# Disallow: /homedetail/HomeDetail,*Border.*debug*DebugBar.*InspectorButton.link.sdirect
# Disallow: /homedetails/*view=owner
# Disallow: /homedetails/*/rental-manager/resources/
# Disallow: /homedetails/*/*/?altId
# Disallow: /homeimprovement/EmbeddedProfile.htm
# Disallow: /homepage/HomepageVideoMetrics.htm
# Disallow: /homes/*+
# Disallow: /homes/*_rb
# Disallow: /homes/*_zpid/
# Disallow: /homes/*mapBounds*
# Disallow: /homes/com.zillow.service.search.SearchURLImpl
# Disallow: /homes/comps_for_rent/
# Disallow: /homes/comps_for_sale/
# Disallow: /homes/comps/
# Disallow: /homes/for_sale/*_agent_list/
# Disallow: /homes/for_sale/1_favorite_list/1_rs/1_fr/
# Disallow: /howto/GoodNeighborPolicy.htm
# Disallow: /HYx10rg3/xhr/api/v1/collector
# Disallow: /HYx10rg3/xhr/api/v2/collector
# Disallow: /IMAGE
# Disallow: /imf-fetch-message/api/v1/request/fetch-message/MOBILE_APP_UPSELL
# Disallow: /instant-offers/version/
# Disallow: /jmp/questionnaire-eligibility-check
# Disallow: /l/
# Disallow: /learnmore/
# Disallow: /license/
# Disallow: /m/
# Disallow: /make-me-move?zpid=
# Disallow: /make-me-move/?zpid=
# Disallow: /mobile/GetAdConfiguration.htm
# Disallow: /mobile/MobilePropertyDetails.htm
# Disallow: /mobile/WinmoPropertyDetails.htm
# Disallow: /mobile/WPPropertyDetails.htm
# Disallow: /mortgage/SmallMortgageLoanCalculatorWidget.htm
# Disallow: /mortgage/MortgageCalculatorWidgetLarge.htm
# Disallow: /mortgage/MortgageRateTable.htm
# Disallow: /mortgage/widgets/AffordabilityCalculatorWidget.htm
# Disallow: /mortgage/MortgageRateTableWidget.htm
# Disallow: /mortgage/MortgageLoanCalculatorWidget.htm
# Disallow: /mortgage/RateExplorerGraphWidget.htm
# Disallow: /myzillow/
# Disallow: /offers/request/
# Disallow: /ofr/api/v3/questionnaire
# Disallow: /pbflex/
# Disallow: /personalization/
# Disallow: /post-real-estate-listings?zpid=
# Disallow: /post-real-estate-listings/?zpid=
# Disallow: /post-rental-listings?zpid=
# Disallow: /postings/
# Disallow: /postings/PostForSale.htm?
# Disallow: /postings/PostMakeMeMoveStreamlined.htm?
# Disallow: */pre-foreclosure/*
# Disallow: /pricing/
# Disallow: /profile/*/Advice/
# Disallow: /profile/*/Reviews-Written/
# Disallow: /profile/*/photos/
# Disallow: /profiles/ProfileBorderTemplate,*myzillow*MyListingsTabulated.*postings*owners*OwnersProfileUpsell.*DirectLink.sdirect
# Disallow: /real-estate-listings
# Disallow: /rental-manager/?source=topnav&itc=postbutton_topnav
# Disallow: /rental-manager/?zpid=
# Disallow: /rental-manager/properties?postingPath=true
# Disallow: /rental-manager/properties/?source=*
# Disallow: /rental-manager/r/
# Disallow: /rentals/
# Disallow: /rentalsrevenue/
# Disallow: /rentalsrevenue/resume/UpdatePasswordInline*
# Disallow: /renter-hub/
# Disallow: /research/monthly-reports/
# Disallow: /reviews/write?s=
# Disallow: /reviews/write/?s=
# Disallow: /routing/email/
# Disallow: /s/
# Disallow: /savedhomes/
# Disallow: /schools/TestHistoryAsync.htm
# Disallow: /search/browse/HDPTree,*Border.*debug*DebugBar.*InspectorButton.link.sdirect
# Disallow: /search/HDPMapResults.htm
# Disallow: /search/SavedSearchLightboxContent.htm
# Disallow: /showcase/Click.htm?
# Disallow: /sitemap/catalog/hdp/
# Disallow: /trk/
# Disallow: /ui/
# Disallow: /url-shortner/
# Disallow: /user/account/SaveSearchOptions.htm
# Disallow: /user/account/services/
# Disallow: /user/account/services/WhoAmI.htm
# Disallow: /user/acct/login/
# Disallow: /user/InlineLogin.htm?
# Disallow: /user/Login
# Disallow: /user/Register
# Disallow: /util/ClientLogger.htm
# Disallow: /videodetails/
# Disallow: /walkscore/
# Disallow: /webservice/
# Disallow: /webtools/
# Disallow: /widgets/
# Disallow: /wikipages/
# Disallow: /ajax/profile-broker-website
# Disallow: /agent-resources/zgwp/app/themes/paxl/assets/fonts/stargate.ttf
# Disallow: /my-agent/eligibility*
# Disallow: /jsonp/Bdp.htm?*
# Disallow: /ajax/homedetail/MarkPropertyViewed*
# Disallow: /wiki/Help*
# Disallow: */allunits/*
# Disallow: /reviews/batch-request/
# Disallow: /myzillow/ChangePassword.htm
# Disallow: /editing/EditHomeFacts.htm
# Disallow: /community/error-subdivision-name-unavailable/
# Disallow: /user/account/
# Disallow: /user/InlineLogin.htm
# Disallow: /reviews/request/
# Disallow: /CountyAssessorPage.htm
# Disallow: /error/PageNotFound.htm
# Disallow: /mortgage/MortgageRateTableWidget.htm
# Disallow: /imf-fetch-message/*
# Disallow: /app$
# Disallow: /*/node_modules/.bin/jest
# Disallow: /view-3d-home
# Disallow: /b/*/*_p/
#
# User-agent: Mediapartners-Google
# Disallow: /*?searchQueryState=*
#
# User-agent: AdsBot-Google-Mobile
# Disallow: /*?searchQueryState=*
#
# User-agent: AdsBot-Google
# Disallow: /*?searchQueryState=*
# Disallow: /*/*/?utm_content=
# Disallow: /*/?utm_content=
#
# Sitemap: https://mortgageapi.zillow.com/sitemap.xml
# Sitemap: https://www.zillow.com/sitemap/catalog/cdp/index.xml
# Sitemap: https://www.zillow.com/sitemap/catalog/sitemap.xml
# Sitemap: https://www.zillow.com/sitemap/xml/index.xml
# Sitemap: https://www.zillow.com/sitemap/xml/srp-index.xml

# %%
url = 'https://www.city-data.com/robots.txt'
response  = requests.get(url)
print(response.text)
# Out:
# User-agent: Mediapartners-Google
# Disallow:
#
# User-agent: Mediapartners-Google*
# Disallow:
#
#
# User-agent: *
# Disallow: /forum/search.php*
# Disallow: /forum/reputation.php*
# Disallow: /forum/members
# Disallow: /forum/newreply.php*
# Disallow: /cityname.php*
# Disallow: /cityname2.php*
# Disallow: /news/
# Disallow: /forum2/
# Disallow: /forumc/
# Disallow: /forumbeta/
# Disallow: /cityw/
# Disallow: /roost_ads/
# Disallow: /cd_ads/
# Disallow: /forum/fort-myers-cape-coral-area/515615-beware-dr-robert-di-fronzo.html
# Disallow: /bs/
# Disallow: /business-profiles/map.php*
# Disallow: /so/*.js
# Disallow: /soz/*.js
# Disallow: /knowledge/
# Disallow: /mapIt.html*
# Disallow: /restaurants/afd.class.php*
# Disallow: /city/js/getBoxes.php*
# Disallow: /county/js/getBoxes.php*
# Disallow: /zips/js/getBoxes.php*
# Disallow: /neighborhood/js/getBoxes.php*
# Disallow: /mtc.class.php*
# Disallow: /restaurants/menus/
# Disallow: /mod_comments/*
#
# User-agent: 008
# Disallow: /
#
# User-agent: sitebot
# Disallow: /
#
# User-agent: businessdbbot
# Disallow: /
#
# User-agent: magpie-crawle
# Disallow: /
#
# User-agent: Bender
# Disallow: /
#
# User-agent: MJ12bot
# Disallow: /
#
# User-agent: JikeSpider
# Disallow: /
#
# User-agent: AhrefsBot
# Disallow: /
#
# User-agent: proximic
# Disallow: /
#
# User-agent: ADmantX
# Disallow: /
#
# User-agent: Mediapartners-Google
# Allow: /knowledge
