# %% [markdown]
# # Regresssion

# %%
import pickle
with open('property_corr0511','rb') as read_file:
    property_corr = pickle.load(read_file)

# %%
property_corr
# Out:
#                                percentage_of_taxable_dollars  fireplaces  \
# percentage_of_taxable_dollars                       1.000000    0.106328
# fireplaces                                          0.106328    1.000000
# garage_spaces                                       0.006343    0.127019
# number_of_bathrooms                                -0.067777    0.152170
# number_of_bedrooms                                 -0.072873    0.073997
# number_stories                                      0.100535    0.009223
# total_area                                          0.055285    0.246083
# percent_female_2016                                -0.077723    0.047521
# land_area_sqmi                                     -0.027770    0.008744
# water_area_sqmi                                     0.022264   -0.059461
# unemployment                                        0.028391    0.061139
# percent_change_in_pop_00_16                         0.036595    0.058560
#
# ...

# %% [markdown]
# Current R2: 0.04
