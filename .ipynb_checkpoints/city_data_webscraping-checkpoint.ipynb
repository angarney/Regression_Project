# %% [markdown]
# # City-Data Web Scraping

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time, os
import numpy as np
import random
import re
import pickle
import urllib.request, urllib.error, urllib.parse
import pandas as pd

# %% [markdown]
# ### Pulling Zipcode Specific Information on City-Data.com

# %%
#Pull City-Data HTML with link

city_data_link = 'https://www.city-data.com/zipmaps/Philadelphia-Pennsylvania.html'
city_data_html = requests.get(city_data_link).text
city_data_soup = BeautifulSoup(city_data_html, "lxml")

# %%
#Pull City-Data saved html

with open('philadelphia_info_by_zip.html') as page:
    property_html = page.read()
city_soup = BeautifulSoup(property_html, "lxml")

# %%
#Get all zipcodes function

def get_zipcodes(soup):
    phila_zip_list = []
    for div in soup.findAll('div', attrs={'class' : 'zip data-block'}):
        phila_zip_list.append(div.get('id'))
    return phila_zip_list

# %%
#Get Philly zipcodes

phila_zip_list = get_zipcodes(city_soup)

#Remove 19112 - Philadelphia Naval Yard area
phila_zip_list.remove('19112')

#Check final zipcode list
phila_zip_list
# Out:
# ['19102',
#  '19103',
#  '19104',
#  '19106',
#  '19107',
#  '19111',
#  '19114',
#  '19115',
#  '19116',
#  '19118',
#  '19119',
#  '19120',
#  '19121',
#  '19122',
#  '19123',
#  '19124',
#  '19125',
#  '19126',
#  '19127',
#  '19128',
#  '19129',
#  '19130',
#  '19131',
#  '19132',
#  '19133',
#  '19134',
#  '19135',
#  '19136',
#  '19137',
#  '19138',
#  '19139',
#  '19140',
#  '19141',
#  '19142',
#  '19143',
#  '19144',
#  '19145',
#  '19146',
#  '19147',
#  '19148',
#  '19149',
#  '19150',
#  '19151',
#  '19152',
#  '19153',
#  '19154']

# %%
#Pickle zipcodes

with open('philly_zipcodes', 'wb') as philly_zipcodes:
    pickle.dump(phila_zip_list, philly_zipcodes)

# %%
#Pull information for single zipcode

def get_zipcode_info(soup,zipcode):
    
    zipcode_statistics = soup.find('div', attrs={'id' : zipcode}).find_all('b')
    
    zipcode_info_list = []
    
    for item in zipcode_statistics:
        zipcode_info_list.append(item.nextSibling)
        
    zipcode = zipcode
    population_2016 = zipcode_info_list[0].replace(',','').strip() 
    population_2010 = zipcode_info_list[1].replace(',','').strip()         
    population_2000 = zipcode_info_list[2].replace(',','').strip()
    costofliving_index_2016 = zipcode_info_list[3].strip()
    land_area_sqmi = zipcode_info_list[5].strip()
    water_area_sqmi = zipcode_info_list[7].strip()
    population_dentisty_per_sqmi = zipcode_info_list[9].replace(',','').strip()
    population_2016_male = re.sub('[A-Za-z,]','',zipcode_info_list[11]).strip()
    population_2016_female = zipcode_info_list[12].replace(',','').strip()
    property_tax = zipcode_info_list[13].replace('%','').strip()[:3]
    med_tax_morg_2016 = zipcode_info_list[14].replace('$','').replace(',','').strip()[:-6]
    med_tax_nomorg_2016 = zipcode_info_list[15].replace('$','').replace(',','').strip()[:-6]
    med_house_value_2016 = zipcode_info_list[16].replace('$','').replace(',','').strip()
    med_house_income_2016 = zipcode_info_list[17].replace('$','').replace(',','').strip()
    med_owner_cost_morg = zipcode_info_list[18].replace('$','').replace(',','').strip()
    med_owner_cost_nomorg = zipcode_info_list[19].replace('$','').replace(',','').strip()
    med_rent_2016 = zipcode_info_list[20].replace('$','').replace(',','').strip()
    med_asking_price_2016 = zipcode_info_list[21].replace('$','').replace(',','').strip()
    unemployment = zipcode_info_list[22].replace('%','').replace(':','').strip()
        
    city_data_dict = dict(zip(headers, [zipcode, population_2016, population_2010, population_2000,
    costofliving_index_2016, land_area_sqmi, water_area_sqmi,
    population_dentisty_per_sqmi, population_2016_male, population_2016_female,
    property_tax, med_tax_morg_2016, med_tax_nomorg_2016, med_house_value_2016,
    med_house_income_2016, med_owner_cost_morg, med_owner_cost_nomorg, med_rent_2016, 
    med_asking_price_2016, unemployment]))
    
    city_data.append(city_data_dict)
    
    return print(zipcode, 'added')

# %%
#Pull information for all zipcodes

city_data = []

headers = ['zipcode', 'population_2016', 'population_2010', 'population_2000',
    'costofliving_index_2016', 'land_area_sqmi', 'water_area_sqmi',
    'population_dentisty_per_sqmi', 'population_2016_male', 'population_2016_female',
    'property_tax', 'med_tax_morg_2016', 'med_tax_nomorg_2016', 'med_house_value_2016',
    'med_house_income_2016', 'med_owner_cost_morg', 'med_owner_cost_nomorg', 'med_rent_2016', 
    'med_asking_price_2016', 'unemployment']

def pull_all_zipcodes(soup,zipcode_list):
    
    for zipcode in zipcode_list:
        get_zipcode_info(soup,zipcode)       

    return city_data

# %%
#Pull all zipcode information through function
pull_all_zipcodes(city_soup, phila_zip_list)
# Out:
# 19102 added
# 19103 added
# 19104 added
# 19106 added
# 19107 added
# 19111 added
# 19114 added
# 19115 added
# 19116 added
# 19118 added
# 19119 added
# 19120 added
# 19121 added
# 19122 added
# 19123 added
# 19124 added
# 19125 added
# 19126 added
# 19127 added
# 19128 added
# 19129 added
# 19130 added
# 19131 added
# 19132 added
# 19133 added
# 19134 added
# 19135 added
# 19136 added
# 19137 added
# 19138 added
# 19139 added
# 19140 added
# 19141 added
# 19142 added
# 19143 added
# 19144 added
# 19145 added
# 19146 added
# 19147 added
# 19148 added
# 19149 added
# 19150 added
# 19151 added
# 19152 added
# 19153 added
# 19154 added
# [{'zipcode': '19102',
#   'population_2016': '4936',
#   'population_2010': '4705',
#   'population_2000': '4396',
#   'costofliving_index_2016': '110.5',
#   'land_area_sqmi': '0.2',
#   'water_area_sqmi': '0.0',
#   'population_dentisty_per_sqmi': '26137',
#   'population_2016_male': '2504',
#   'population_2016_female': '2432',
#   'property_tax': '1.0',
#   'med_tax_morg_2016': '4331 ',
#   'med_tax_nomorg_2016': '4014 ',
#   'med_house_value_2016': '427870',
#   'med_house_income_2016': '101898',
#   'med_owner_cost_morg': '3001',
#   'med_owner_cost_nomorg': '978',
#   'med_rent_2016': '2082',
#   'med_asking_price_2016': '1081578',
#   'unemployment': '2.5'},
#  {'zipcode': '19103',
#   'population_2016': '23239',
#   'population_2010': '21908',
#   'population_2000': '19714',
#   'costofliving_index_2016': '112.3',
#   'land_area_sqmi': '0.6',
#   'water_area_sqmi': '0.0',
#   'population_dentisty_per_sqmi': '36367',
#   'population_2016_male': '10223',
#   'population_2016_female': '13015',
#   'property_tax': '0.9',
#   'med_tax_morg_2016': '5126 ',
#   'med_tax_nomorg_2016': '3242 ',
#   'med_house_value_2016': '521102',
#   'med_house_income_2016': '73681',
#   'med_owner_cost_morg': '2940',
#   'med_owner_cost_nomorg': '795',
#   'med_rent_2016': '1601',
#   'med_asking_price_2016': '362650',
#   'unemployment': '2.9'},
#  {'zipcode': '19104',
#   'population_2016': '55677',
#   'population_2010': '51808',
#   'population_2000': '50125',
#   'costofliving_index_2016': '107.1',
#   'land_area_sqmi': '3.0',
#   'water_area_sqmi': '0.1',
#   'population_dentisty_per_sqmi': '18519',
#   'population_2016_male': '28105',
#   'population_2016_female': '27571',
#   'property_tax': '0.8',
#   'med_tax_morg_2016': '1781 ',
#   'med_tax_nomorg_2016': '729 ',
#   'med_house_value_2016': '128194',
#   'med_house_income_2016': '22676',
#   'med_owner_cost_morg': '1187',
#   'med_owner_cost_nomorg': '413',
#   'med_rent_2016': '941',
#   'med_asking_price_2016': '222828',
#   'unemployment': '7.0'},
#  {'zipcode': '19106',
#   'population_2016': '12268',
#   'population_2010': '11740',
#   'population_2000': '8359',
#   'costofliving_index_2016': '109.6',
#   'land_area_sqmi': '0.8',
#   'water_area_sqmi': '0.4',
#   'population_dentisty_per_sqmi': '15180',
#   'population_2016_male': '6230',
#   'population_2016_female': '6037',
#   'property_tax': '0.9',
#   'med_tax_morg_2016': '3562 ',
#   'med_tax_nomorg_2016': '6231 ',
#   'med_house_value_2016': '497794',
#   'med_house_income_2016': '105334',
#   'med_owner_cost_morg': '2615',
#   'med_owner_cost_nomorg': '1242',
#   'med_rent_2016': '1737',
#   'med_asking_price_2016': '567543',
#   'unemployment': '2.5'},
#  {'zipcode': '19107',
#   'population_2016': '13657',
#   'population_2010': '14875',
#   'population_2000': '12340',
#   'costofliving_index_2016': '110.6',
#   'land_area_sqmi': '0.5',
#   'water_area_sqmi': '0.0',
#   'population_dentisty_per_sqmi': '24867',
#   'population_2016_male': '6736',
#   'population_2016_female': '6920',
#   'property_tax': '0.8',
#   'med_tax_morg_2016': '3092 ',
#   'med_tax_nomorg_2016': '3049 ',
#   'med_house_value_2016': '374150',
#   'med_house_income_2016': '52804',
#   'med_owner_cost_morg': '1830',
#   'med_owner_cost_nomorg': '936',
#   'med_rent_2016': '1237',
#   'med_asking_price_2016': '408260',
#   'unemployment': '5.4'},
#  {'zipcode': '19111',
#   'population_2016': '70919',
#   'population_2010': '63090',
#   'population_2000': '58874',
#   'costofliving_index_2016': '104.9',
#   'land_area_sqmi': '4.8',
#   'water_area_sqmi': '0.0',
#   'population_dentisty_per_sqmi': '14679',
#   'population_2016_male': '34417',
#   'population_2016_female': '36501',
#   'property_tax': '1.1',
#   'med_tax_morg_2016': '2091 ',
#   'med_tax_nomorg_2016': '2207 ',
#   'med_house_value_2016': '188684',
#   'med_house_income_2016': '46593',
#   'med_owner_cost_morg': '1364',
#   'med_owner_cost_nomorg': '505',
#   'med_rent_2016': '945',
#   'med_asking_price_2016': '173483',
#   'unemployment': '9.1'},
#  {'zipcode': '19114',
#   'population_2016': '31078',
#   'population_2010': '30907',
#   'population_2000': '31083',
#   'costofliving_index_2016': '105.0',
#   'land_area_sqmi': '5.6',
#   'water_area_sqmi': '0.3',
#   'population_dentisty_per_sqmi': '5550',
#   'population_2016_male': '14983',
#   'population_2016_female': '16094',
#   'property_tax': '1.1',
#   'med_tax_morg_2016': '2288 ',
#   'med_tax_nomorg_2016': '2365 ',
#   'med_house_value_2016': '209884',
#   'med_house_income_2016': '56397',
#   'med_owner_cost_morg': '1486',
#   'med_owner_cost_nomorg': '527',
#   'med_rent_2016': '1068',
#   'med_asking_price_2016': '177689',
#   'unemployment': '6.1'},
#  {'zipcode': '19115',
#   'population_2016': '33050',
#   'population_2010': '33207',
#   'population_2000': '31853',
#   'costofliving_index_2016': '106.8',
#   'land_area_sqmi': '5.6',
#   'water_area_sqmi': '0.1',
#   'population_dentisty_per_sqmi': '5887',
#   'population_2016_male': '15570',
#   'population_2016_female': '17479',
#   'property_tax': '1.1',
#   'med_tax_morg_2016': '2872 ',
#   'med_tax_nomorg_2016': '2915 ',
#   'med_house_value_2016': '261605',
#   'med_house_income_2016': '49357',
#   'med_owner_cost_morg': '1675',
#   'med_owner_cost_nomorg': '583',
#   'med_rent_2016': '976',
#   'med_asking_price_2016': '231775',
#   'unemployment': '4.9'},
#  {'zipcode': '19116',
#   'population_2016': '33688',
#   'population_2010': '33112',
#   'population_2000': '32560',
#   'costofliving_index_2016': '106.7',
#   'land_area_sqmi': '5.0',
#   'water_area_sqmi': '0.0',
#   'population_dentisty_per_sqmi': '6731',
#   'population_2016_male': '15874',
#   'population_2016_female': '17813',
#   'property_tax': '1.1',
#   'med_tax_morg_2016': '2746 ',
#   'med_tax_nomorg_2016': '2827 ',
#   'med_house_value_2016': '259274',
#   'med_house_income_2016': '48247',
#   'med_owner_cost_morg': '1629',
#   'med_owner_cost_nomorg': '568',
#   'med_rent_2016': '931',
#   'med_asking_price_2016': '203806',
#   'unemployment': '6.1'},
#  {'zipcode': '19118',
#   'population_2016': '10690',
#   'population_2010': '9808',
#   'population_2000': '9608',
#   'costofliving_index_2016': '110.8',
#   'land_area_sqmi': '3.2',
#   'water_area_sqmi': '0.0',
#   'population_dentisty_per_sqmi': '3351',
#   'population_2016_male': '4758',
#   'population_2016_female': '5931',
#   'property_tax': '1.0',
#   'med_tax_morg_2016': '5407 ',
#   'med_tax_nomorg_2016': '6147 ',
#   'med_house_value_2016': '538638',
#   'med_house_income_2016': '82904',
#   'med_owner_cost_morg': '2601',
#   'med_owner_cost_nomorg': '945',
#   'med_rent_2016': '1468',
#   'med_asking_price_2016': '846508',
#   'unemployment': '3.8'},
#  {'zipcode': '19119',
#   'population_2016': '29015',
#   'population_2010': '27035',
#   'population_2000': '28873',
#   'costofliving_index_2016': '105.6',
#   'land_area_sqmi': '3.2',
#   'water_area_sqmi': '0.0',
#   'population_dentisty_per_sqmi': '8964',
#   'population_2016_male': '13485',
#   'population_2016_female': '15529',
#   'property_tax': '1.0',
#   'med_tax_morg_2016': '2665 ',
#   'med_tax_nomorg_2016': '2535 ',
#   'med_house_value_2016': '263492',
#   'med_house_income_2016': '59948',
#   'med_owner_cost_morg': '1600',
#   'med_owner_cost_nomorg': '595',
#   'med_rent_2016': '1000',
#   'med_asking_price_2016': '306518',
#   'unemployment': '7.7'},
#  {'zipcode': '19120',
#   'population_2016': '77555',
#   'population_2010': '68104',
#   'population_2000': '68831',
#   'costofliving_index_2016': '103.4',
#   'land_area_sqmi': '3.4',
#   'water_area_sqmi': '0.0',
#   'population_dentisty_per_sqmi': '22786',
#   'population_2016_male': '37283',
#   'population_2016_female': '40271',
#   'property_tax': '1.2',
#   'med_tax_morg_2016': '1259 ',
#   'med_tax_nomorg_2016': '1250 ',
#   'med_house_value_2016': '107106',
#   'med_house_income_2016': '36160',
#   'med_owner_cost_morg': '999',
#   'med_owner_cost_nomorg': '390',
#   'med_rent_2016': '968',
#   'med_asking_price_2016': '104071',
#   'unemployment': '14.5'},
#  {'zipcode': '19121',
#   'population_2016': '33119',
#   'population_2010': '36572',
#   'population_2000': '34935',
#   'costofliving_index_2016': '105.3',
#   'land_area_sqmi': '2.2',
#   'water_area_sqmi': '0.1',
#   'population_dentisty_per_sqmi': '14978',
#   'population_2016_male': '14861',
#   'population_2016_female': '18256',
#   'property_tax': '0.6',
#   'med_tax_morg_2016': '778 ',
#   'med_tax_nomorg_2016': '437 ',
#   'med_house_value_2016': '98005',
#   'med_house_income_2016': '19660',
#   'med_owner_cost_morg': '918',
#   'med_owner_cost_nomorg': '377',
#   'med_rent_2016': '750',
#   'med_asking_price_2016': '112356',
#   'unemployment': '12.9'},
#  {'zipcode': '19122',
#   'population_2016': '22392',
#   'population_2010': '21653',
#   'population_2000': '19589',
#   'costofliving_index_2016': '105.3',
#   'land_area_sqmi': '1.3',
#   'water_area_sqmi': '0.0',
#   'population_dentisty_per_sqmi': '17642',
#   'population_2016_male': '11119',
#   'population_2016_female': '11273',
#   'property_tax': '0.6',
#   'med_tax_morg_2016': '1025 ',
#   'med_tax_nomorg_2016': '897 ',
#   'med_house_value_2016': '170704',
#   'med_house_income_2016': '34836',
#   'med_owner_cost_morg': '1060',
#   'med_owner_cost_nomorg': '380',
#   'med_rent_2016': '776',
#   'med_asking_price_2016': '198075',
#   'unemployment': '9.9'},
#  {'zipcode': '19123',
#   'population_2016': '15036',
#   'population_2010': '13416',
#   'population_2000': '9818',
#   'costofliving_index_2016': '108.7',
#   'land_area_sqmi': '1.3',
#   'water_area_sqmi': '0.1',
#   'population_dentisty_per_sqmi': '11896',
#   'population_2016_male': '7189',
#   'population_2016_female': '7846',
#   'property_tax': '0.6',
#   'med_tax_morg_2016': '2143 ',
#   'med_tax_nomorg_2016': '1824 ',
#   'med_house_value_2016': '352174',
#   'med_house_income_2016': '60191',
#   'med_owner_cost_morg': '1802',
#   'med_owner_cost_nomorg': '517',
#   'med_rent_2016': '1210',
#   'med_asking_price_2016': '344502',
#   'unemployment': '7.9'},
#  {'zipcode': '19124',
#   'population_2016': '70116',
#   'population_2010': '66691',
#   'population_2000': '63131',
#   'costofliving_index_2016': '103.8',
#   'land_area_sqmi': '4.9',
#   'water_area_sqmi': '0.0',
#   'population_dentisty_per_sqmi': '14383',
#   'population_2016_male': '32198',
#   'population_2016_female': '37916',
#   'property_tax': '1.1',
#   'med_tax_morg_2016': '1258 ',
#   'med_tax_nomorg_2016': '1067 ',
#   'med_house_value_2016': '108105',
#   'med_house_income_2016': '31532',
#   'med_owner_cost_morg': '1038',
#   'med_owner_cost_nomorg': '378',
#   'med_rent_2016': '903',
#   'med_asking_price_2016': '136644',
#   'unemployment': '15.2'},
#  {'zipcode': '19125',
#   'population_2016': '24855',
#   'population_2010': '22958',
#   'population_2000': '23646',
#   'costofliving_index_2016': '105.1',
#   'land_area_sqmi': '1.4',
#   'water_area_sqmi': '0.2',
#   'population_dentisty_per_sqmi': '18062',
#   'population_2016_male': '12794',
#   'population_2016_female': '12061',
#   'property_tax': '0.6',
#   'med_tax_morg_2016': '1297 ',
#   'med_tax_nomorg_2016': '955 ',
#   'med_house_value_2016': '216987',
#   'med_house_income_2016': '54678',
#   'med_owner_cost_morg': '1313',
#   'med_owner_cost_nomorg': '386',
#   'med_rent_2016': '1022',
#   'med_asking_price_2016': '184084',
#   'unemployment': '9.6'},
#  {'zipcode': '19126',
#   'population_2016': '15559',
#   'population_2010': '15758',
#   'population_2000': '16484',
#   'costofliving_index_2016': '105.0',
#   'land_area_sqmi': '1.1',
#   'water_area_sqmi': '0.0',
#   'population_dentisty_per_sqmi': '13615',
#   'population_2016_male': '7091',
#   'population_2016_female': '8467',
#   'property_tax': '1.0',
#   'med_tax_morg_2016': '1719 ',
#   'med_tax_nomorg_2016': '1531 ',
#   'med_house_value_2016': '155942',
#   'med_house_income_2016': '36631',
#   'med_owner_cost_morg': '1368',
#   'med_owner_cost_nomorg': '510',
#   'med_rent_2016': '914',
#   'med_asking_price_2016': '181244',
#   'unemployment': '11.5'},
#  {'zipcode': '19127',
#   'population_2016': '6352',
#   'population_2010': '5913',
#   'population_2000': '5465',
#   'costofliving_index_2016': '106.2',
#   'land_area_sqmi': '0.5',
#   'water_area_sqmi': '0.1',
#   'population_dentisty_per_sqmi': '11557',
#   'population_2016_male': '3504',
#   'population_2016_female': '2848',
#   'property_tax': '0.8',
#   'med_tax_morg_2016': '2448 ',
#   'med_tax_nomorg_2016': '1865 ',
#   'med_house_value_2016': '255057',
#   'med_house_income_2016': '73495',
#   'med_owner_cost_morg': '1851',
#   'med_owner_cost_nomorg': '475',
#   'med_rent_2016': '1406',
#   'med_asking_price_2016': '222828',
#   'unemployment': '2.2'},
#  {'zipcode': '19128',
#   'population_2016': '37488',
#   'population_2010': '35239',
#   'population_2000': '36420',
#   'costofliving_index_2016': '106.1',
#   'land_area_sqmi': '7.1',
#   'water_area_sqmi': '0.1',
#   'population_dentisty_per_sqmi': '5306',
#   'population_2016_male': '18033',
#   'population_2016_female': '19454',
#   'property_tax': '1.0',
#   'med_tax_morg_2016': '2602 ',
#   'med_tax_nomorg_2016': '2590 ',
#   'med_house_value_2016': '260717',
#   'med_house_income_2016': '66695',
#   'med_owner_cost_morg': '1640',
#   'med_owner_cost_nomorg': '535',
#   'med_rent_2016': '1245',
#   'med_asking_price_2016': '191853',
#   'unemployment': '4.4'},
#  {'zipcode': '19129',
#   'population_2016': '11176',
#   'population_2010': '10975',
#   'population_2000': '10748',
#   'costofliving_index_2016': '106.5',
#   'land_area_sqmi': '2.2',
#   'water_area_sqmi': '0.1',
#   'population_dentisty_per_sqmi': '5083',
#   'population_2016_male': '5342',
#   'population_2016_female': '5833',
#   'property_tax': '0.8',
#   'med_tax_morg_2016': '2016 ',
#   'med_tax_nomorg_2016': '1453 ',
#   'med_house_value_2016': '215544',
#   'med_house_income_2016': '49934',
#   'med_owner_cost_morg': '1448',
#   'med_owner_cost_nomorg': '407',
#   'med_rent_2016': '1207',
#   'med_asking_price_2016': '5954300',
#   'unemployment': '7.1'},
#  {'zipcode': '19130',
#   'population_2016': '27148',
#   'population_2010': '24870',
#   'population_2000': '22874',
#   'costofliving_index_2016': '108.2',
#   'land_area_sqmi': '1.3',
#   'water_area_sqmi': '0.1',
#   'population_dentisty_per_sqmi': '20973',
#   'population_2016_male': '13871',
#   'population_2016_female': '13277',
#   'property_tax': '0.9',
#   'med_tax_morg_2016': '3399 ',
#   'med_tax_nomorg_2016': '3301 ',
#   'med_house_value_2016': '381253',
#   'med_house_income_2016': '74219',
#   'med_owner_cost_morg': '2002',
#   'med_owner_cost_nomorg': '648',
#   'med_rent_2016': '1328',
#   'med_asking_price_2016': '280069',
#   'unemployment': '3.9'},
#  {'zipcode': '19131',
#   'population_2016': '42396',
#   'population_2010': '43172',
#   'population_2000': '47044',
#   'costofliving_index_2016': '104.4',
#   'land_area_sqmi': '5.3',
#   'water_area_sqmi': '0.3',
#   'population_dentisty_per_sqmi': '8034',
#   'population_2016_male': '18304',
#   'population_2016_female': '24090',
#   'property_tax': '1.0',
#   'med_tax_morg_2016': '1431 ',
#   'med_tax_nomorg_2016': '1103 ',
#   'med_house_value_2016': '119759',
#   'med_house_income_2016': '32404',
#   'med_owner_cost_morg': '1106',
#   'med_owner_cost_nomorg': '429',
#   'med_rent_2016': '954',
#   'med_asking_price_2016': '112123',
#   'unemployment': '9.2'},
#  {'zipcode': '19132',
#   'population_2016': '35086',
#   'population_2010': '36268',
#   'population_2000': '41709',
#   'costofliving_index_2016': '101.8',
#   'land_area_sqmi': '2.2',
#   'water_area_sqmi': '0.0',
#   'population_dentisty_per_sqmi': '16211',
#   'population_2016_male': '15985',
#   'population_2016_female': '19099',
#   'property_tax': '0.9',
#   'med_tax_morg_2016': '544 ',
#   'med_tax_nomorg_2016': '486 ',
#   'med_house_value_2016': '53720',
#   'med_house_income_2016': '23242',
#   'med_owner_cost_morg': '785',
#   'med_owner_cost_nomorg': '333',
#   'med_rent_2016': '815',
#   'med_asking_price_2016': '222828',
#   'unemployment': '13.5'},
#  {'zipcode': '19133',
#   'population_2016': '27195',
#   'population_2010': '26063',
#   'population_2000': '27971',
#   'costofliving_index_2016': '102.2',
#   'land_area_sqmi': '1.3',
#   'water_area_sqmi': '0.0',
#   'population_dentisty_per_sqmi': '20909',
#   'population_2016_male': '12792',
#   'population_2016_female': '14402',
#   'property_tax': '0.6',
#   'med_tax_morg_2016': '478 ',
#   'med_tax_nomorg_2016': '281 ',
#   'med_house_value_2016': '56272',
#   'med_house_income_2016': '18871',
#   'med_owner_cost_morg': '855',
#   'med_owner_cost_nomorg': '309',
#   'med_rent_2016': '693',
#   'med_asking_price_2016': '222828',
#   'unemployment': '18.5'},
#  {'zipcode': '19134',
#   'population_2016': '65008',
#   'population_2010': '60675',
#   'population_2000': '57922',
#   'costofliving_index_2016': '103.2',
#   'land_area_sqmi': '3.5',
#   'water_area_sqmi': '0.3',
#   'population_dentisty_per_sqmi': '18530',
#   'population_2016_male': '31568',
#   'population_2016_female': '33439',
#   'property_tax': '1.0',
#   'med_tax_morg_2016': '952 ',
#   'med_tax_nomorg_2016': '837 ',
#   'med_house_value_2016': '90901',
#   'med_house_income_2016': '29101',
#   'med_owner_cost_morg': '875',
#   'med_owner_cost_nomorg': '359',
#   'med_rent_2016': '876',
#   'med_asking_price_2016': '222828',
#   'unemployment': '17.0'},
#  {'zipcode': '19135',
#   'population_2016': '32052',
#   'population_2010': '33091',
#   'population_2000': '30881',
#   'costofliving_index_2016': '102.9',
#   'land_area_sqmi': '2.3',
#   'water_area_sqmi': '0.3',
#   'population_dentisty_per_sqmi': '13765',
#   'population_2016_male': '15458',
#   'population_2016_female': '16593',
#   'property_tax': '1.1',
#   'med_tax_morg_2016': '1405 ',
#   'med_tax_nomorg_2016': '1406 ',
#   'med_house_value_2016': '125087',
#   'med_house_income_2016': '43398',
#   'med_owner_cost_morg': '1070',
#   'med_owner_cost_nomorg': '419',
#   'med_rent_2016': '884',
#   'med_asking_price_2016': '118464',
#   'unemployment': '9.0'},
#  {'zipcode': '19136',
#   'population_2016': '34138',
#   'population_2010': '40647',
#   'population_2000': '40080',
#   'costofliving_index_2016': '103.8',
#   'land_area_sqmi': '4.6',
#   'water_area_sqmi': '0.9',
#   'population_dentisty_per_sqmi': '7414',
#   'population_2016_male': '17383',
#   'population_2016_female': '16755',
#   'property_tax': '1.1',
#   'med_tax_morg_2016': '1745 ',
#   'med_tax_nomorg_2016': '1759 ',
#   'med_house_value_2016': '165265',
#   'med_house_income_2016': '48241',
#   'med_owner_cost_morg': '1191',
#   'med_owner_cost_nomorg': '438',
#   'med_rent_2016': '900',
#   'med_asking_price_2016': '180934',
#   'unemployment': '7.5'},
#  {'zipcode': '19137',
#   'population_2016': '8402',
#   'population_2010': '8638',
#   'population_2000': '8069',
#   'costofliving_index_2016': '103.5',
#   'land_area_sqmi': '2.4',
#   'water_area_sqmi': '0.9',
#   'population_dentisty_per_sqmi': '3490',
#   'population_2016_male': '4271',
#   'population_2016_female': '4131',
#   'property_tax': '0.9',
#   'med_tax_morg_2016': '1410 ',
#   'med_tax_nomorg_2016': '1336 ',
#   'med_house_value_2016': '145287',
#   'med_house_income_2016': '52554',
#   'med_owner_cost_morg': '1135',
#   'med_owner_cost_nomorg': '416',
#   'med_rent_2016': '1030',
#   'med_asking_price_2016': '110094',
#   'unemployment': '10.2'},
#  {'zipcode': '19138',
#   'population_2016': '34292',
#   'population_2010': '32273',
#   'population_2000': '34477',
#   'costofliving_index_2016': '103.9',
#   'land_area_sqmi': '1.7',
#   'water_area_sqmi': '0.0',
#   'population_dentisty_per_sqmi': '19903',
#   'population_2016_male': '14777',
#   'population_2016_female': '19514',
#   'property_tax': '1.1',
#   'med_tax_morg_2016': '1367 ',
#   'med_tax_nomorg_2016': '1257 ',
#   'med_house_value_2016': '120203',
#   'med_house_income_2016': '37010',
#   'med_owner_cost_morg': '1077',
#   'med_owner_cost_nomorg': '437',
#   'med_rent_2016': '977',
#   'med_asking_price_2016': '107782',
#   'unemployment': '13.8'},
#  {'zipcode': '19139',
#   'population_2016': '44122',
#   'population_2010': '41271',
#   'population_2000': '43866',
#   'costofliving_index_2016': '103.1',
#   'land_area_sqmi': '1.8',
#   'water_area_sqmi': '0.0',
#   'population_dentisty_per_sqmi': '24928',
#   'population_2016_male': '19121',
#   'population_2016_female': '25000',
#   'property_tax': '0.9',
#   'med_tax_morg_2016': '823 ',
#   'med_tax_nomorg_2016': '745 ',
#   'med_house_value_2016': '85907',
#   'med_house_income_2016': '27449',
#   'med_owner_cost_morg': '873',
#   'med_owner_cost_nomorg': '364',
#   'med_rent_2016': '855',
#   'med_asking_price_2016': '222828',
#   'unemployment': '13.3'},
#  {'zipcode': '19140',
#   'population_2016': '51865',
#   'population_2010': '54133',
#   'population_2000': '57125',
#   'costofliving_index_2016': '102.9',
#   'land_area_sqmi': '3.1',
#   'water_area_sqmi': '0.0',
#   'population_dentisty_per_sqmi': '16992',
#   'population_2016_male': '24712',
#   'population_2016_female': '27152',
#   'property_tax': '0.9',
#   'med_tax_morg_2016': '664 ',
#   'med_tax_nomorg_2016': '593 ',
#   'med_house_value_2016': '68592',
#   'med_house_income_2016': '22527',
#   'med_owner_cost_morg': '759',
#   'med_owner_cost_nomorg': '337',
#   'med_rent_2016': '829',
#   'med_asking_price_2016': '222828',
#   'unemployment': '19.5'},
#  {'zipcode': '19141',
#   'population_2016': '34808',
#   'population_2010': '31376',
#   'population_2000': '34984',
#   'costofliving_index_2016': '103.5',
#   'land_area_sqmi': '1.8',
#   'water_area_sqmi': '0.0',
#   'population_dentisty_per_sqmi': '19193',
#   'population_2016_male': '15674',
#   'population_2016_female': '19133',
#   'property_tax': '1.1',
#   'med_tax_morg_2016': '1209 ',
#   'med_tax_nomorg_2016': '1110 ',
#   'med_house_value_2016': '107328',
#   'med_house_income_2016': '30448',
#   'med_owner_cost_morg': '1064',
#   'med_owner_cost_nomorg': '412',
#   'med_rent_2016': '819',
#   'med_asking_price_2016': '130657',
#   'unemployment': '14.3'},
#  {'zipcode': '19142',
#   'population_2016': '28625',
#   'population_2010': '29595',
#   'population_2000': '29063',
#   'costofliving_index_2016': '103.2',
#   'land_area_sqmi': '1.7',
#   'water_area_sqmi': '0.0',
#   'population_dentisty_per_sqmi': '16978',
#   'population_2016_male': '13341',
#   'population_2016_female': '15283',
#   'property_tax': '1.2',
#   'med_tax_morg_2016': '1066 ',
#   'med_tax_nomorg_2016': '957 ',
#   'med_house_value_2016': '88016',
#   'med_house_income_2016': '31215',
#   'med_owner_cost_morg': '933',
#   'med_owner_cost_nomorg': '380',
#   'med_rent_2016': '964',
#   'med_asking_price_2016': '222828',
#   'unemployment': '13.4'},
#  {'zipcode': '19143',
#   'population_2016': '64429',
#   'population_2010': '64849',
#   'population_2000': '71169',
#   'costofliving_index_2016': '102.8',
#   'land_area_sqmi': '3.2',
#   'water_area_sqmi': '0.1',
#   'population_dentisty_per_sqmi': '20211',
#   'population_2016_male': '29447',
#   'population_2016_female': '34980',
#   'property_tax': '0.9',
#   'med_tax_morg_2016': '920 ',
#   'med_tax_nomorg_2016': '825 ',
#   'med_house_value_2016': '92122',
#   'med_house_income_2016': '32075',
#   'med_owner_cost_morg': '957',
#   'med_owner_cost_nomorg': '415',
#   'med_rent_2016': '854',
#   'med_asking_price_2016': '222828',
#   'unemployment': '14.5'},
#  {'zipcode': '19144',
#   'population_2016': '41195',
#   'population_2010': '43329',
#   'population_2000': '46794',
#   'costofliving_index_2016': '105.0',
#   'land_area_sqmi': '3.4',
#   'water_area_sqmi': '0.0',
#   'population_dentisty_per_sqmi': '11999',
#   'population_2016_male': '18877',
#   'population_2016_female': '22317',
#   'property_tax': '1.1',
#   'med_tax_morg_2016': '1453 ',
#   'med_tax_nomorg_2016': '1310 ',
#   'med_house_value_2016': '128638',
#   'med_house_income_2016': '29209',
#   'med_owner_cost_morg': '1136',
#   'med_owner_cost_nomorg': '453',
#   'med_rent_2016': '866',
#   'med_asking_price_2016': '195486',
#   'unemployment': '11.2'},
#  {'zipcode': '19145',
#   'population_2016': '48587',
#   'population_2010': '47261',
#   'population_2000': '45647',
#   'costofliving_index_2016': '105.4',
#   'land_area_sqmi': '4.9',
#   'water_area_sqmi': '0.3',
#   'population_dentisty_per_sqmi': '9970',
#   'population_2016_male': '23182',
#   'population_2016_female': '25403',
#   'property_tax': '0.8',
#   'med_tax_morg_2016': '1433 ',
#   'med_tax_nomorg_2016': '1344 ',
#   'med_house_value_2016': '174034',
#   'med_house_income_2016': '39796',
#   'med_owner_cost_morg': '1196',
#   'med_owner_cost_nomorg': '420',
#   'med_rent_2016': '954',
#   'med_asking_price_2016': '214731',
#   'unemployment': '9.6'},
#  {'zipcode': '19146',
#   'population_2016': '37767',
#   'population_2010': '35113',
#   'population_2000': '35783',
#   'costofliving_index_2016': '107.1',
#   'land_area_sqmi': '1.7',
#   'water_area_sqmi': '0.1',
#   'population_dentisty_per_sqmi': '22353',
#   'population_2016_male': '17495',
#   'population_2016_female': '20270',
#   'property_tax': '0.4',
#   'med_tax_morg_2016': '1613 ',
#   'med_tax_nomorg_2016': '903 ',
#   'med_house_value_2016': '291129',
#   'med_house_income_2016': '54608',
#   'med_owner_cost_morg': '1803',
#   'med_owner_cost_nomorg': '395',
#   'med_rent_2016': '1039',
#   'med_asking_price_2016': '269196',
#   'unemployment': '6.7'},
#  {'zipcode': '19147',
#   'population_2016': '39405',
#   'population_2010': '36228',
#   'population_2000': '32680',
#   'costofliving_index_2016': '107.6',
#   'land_area_sqmi': '1.4',
#   'water_area_sqmi': '0.2',
#   'population_dentisty_per_sqmi': '27998',
#   'population_2016_male': '19454',
#   'population_2016_female': '19950',
#   'property_tax': '0.7',
#   'med_tax_morg_2016': '2742 ',
#   'med_tax_nomorg_2016': '2077 ',
#   'med_house_value_2016': '357612',
#   'med_house_income_2016': '72963',
#   'med_owner_cost_morg': '1694',
#   'med_owner_cost_nomorg': '497',
#   'med_rent_2016': '1255',
#   'med_asking_price_2016': '395531',
#   'unemployment': '4.8'},
#  {'zipcode': '19148',
#   'population_2016': '54642',
#   'population_2010': '49732',
#   'population_2000': '48573',
#   'costofliving_index_2016': '105.1',
#   'land_area_sqmi': '4.2',
#   'water_area_sqmi': '0.6',
#   'population_dentisty_per_sqmi': '12939',
#   'population_2016_male': '27401',
#   'population_2016_female': '27241',
#   'property_tax': '0.7',
#   'med_tax_morg_2016': '1435 ',
#   'med_tax_nomorg_2016': '1347 ',
#   'med_house_value_2016': '189572',
#   'med_house_income_2016': '48021',
#   'med_owner_cost_morg': '1275',
#   'med_owner_cost_nomorg': '389',
#   'med_rent_2016': '1023',
#   'med_asking_price_2016': '213936',
#   'unemployment': '8.7'},
#  {'zipcode': '19149',
#   'population_2016': '57749',
#   'population_2010': '55006',
#   'population_2000': '48483',
#   'costofliving_index_2016': '104.8',
#   'land_area_sqmi': '2.4',
#   'water_area_sqmi': '0.0',
#   'population_dentisty_per_sqmi': '23778',
#   'population_2016_male': '27813',
#   'population_2016_female': '29935',
#   'property_tax': '1.1',
#   'med_tax_morg_2016': '1547 ',
#   'med_tax_nomorg_2016': '1534 ',
#   'med_house_value_2016': '141846',
#   'med_house_income_2016': '41544',
#   'med_owner_cost_morg': '1141',
#   'med_owner_cost_nomorg': '412',
#   'med_rent_2016': '1114',
#   'med_asking_price_2016': '137090',
#   'unemployment': '9.7'},
#  {'zipcode': '19150',
#   'population_2016': '24725',
#   'population_2010': '23378',
#   'population_2000': '25274',
#   'costofliving_index_2016': '105.0',
#   'land_area_sqmi': '1.5',
#   'water_area_sqmi': '0.0',
#   'population_dentisty_per_sqmi': '16400',
#   'population_2016_male': '10733',
#   'population_2016_female': '13990',
#   'property_tax': '1.0',
#   'med_tax_morg_2016': '1855 ',
#   'med_tax_nomorg_2016': '1813 ',
#   'med_house_value_2016': '177252',
#   'med_house_income_2016': '45594',
#   'med_owner_cost_morg': '1220',
#   'med_owner_cost_nomorg': '470',
#   'med_rent_2016': '1028',
#   'med_asking_price_2016': '162697',
#   'unemployment': '11.2'},
#  {'zipcode': '19151',
#   'population_2016': '34884',
#   'population_2010': '29883',
#   'population_2000': '31255',
#   'costofliving_index_2016': '103.7',
#   'land_area_sqmi': '2.4',
#   'water_area_sqmi': '0.0',
#   'population_dentisty_per_sqmi': '14585',
#   'population_2016_male': '15160',
#   'population_2016_female': '19722',
#   'property_tax': '1.0',
#   'med_tax_morg_2016': '1507 ',
#   'med_tax_nomorg_2016': '1178 ',
#   'med_house_value_2016': '140070',
#   'med_house_income_2016': '46668',
#   'med_owner_cost_morg': '1189',
#   'med_owner_cost_nomorg': '439',
#   'med_rent_2016': '1008',
#   'med_asking_price_2016': '140326',
#   'unemployment': '8.8'},
#  {'zipcode': '19152',
#   'population_2016': '35387',
#   'population_2010': '33293',
#   'population_2000': '31379',
#   'costofliving_index_2016': '105.0',
#   'land_area_sqmi': '2.8',
#   'water_area_sqmi': '0.0',
#   'population_dentisty_per_sqmi': '12554',
#   'population_2016_male': '17079',
#   'population_2016_female': '18307',
#   'property_tax': '1.2',
#   'med_tax_morg_2016': '2499 ',
#   'med_tax_nomorg_2016': '2352 ',
#   'med_house_value_2016': '207109',
#   'med_house_income_2016': '51105',
#   'med_owner_cost_morg': '1430',
#   'med_owner_cost_nomorg': '490',
#   'med_rent_2016': '978',
#   'med_asking_price_2016': '203658',
#   'unemployment': '6.2'},
#  {'zipcode': '19153',
#   'population_2016': '12972',
#   'population_2010': '12259',
#   'population_2000': '12324',
#   'costofliving_index_2016': '104.8',
#   'land_area_sqmi': '7.2',
#   'water_area_sqmi': '1.2',
#   'population_dentisty_per_sqmi': '1812',
#   'population_2016_male': '6133',
#   'population_2016_female': '6838',
#   'property_tax': '1.1',
#   'med_tax_morg_2016': '1795 ',
#   'med_tax_nomorg_2016': '1414 ',
#   'med_house_value_2016': '152390',
#   'med_house_income_2016': '42619',
#   'med_owner_cost_morg': '1326',
#   'med_owner_cost_nomorg': '427',
#   'med_rent_2016': '1078',
#   'med_asking_price_2016': '190050',
#   'unemployment': '9.0'},
#  {'zipcode': '19154',
#   'population_2016': '33634',
#   'population_2010': '34196',
#   'population_2000': '35606',
#   'costofliving_index_2016': '104.9',
#   'land_area_sqmi': '6.3',
#   'water_area_sqmi': '0.1',
#   'population_dentisty_per_sqmi': '5309',
#   'population_2016_male': '16401',
#   'population_2016_female': '17232',
#   'property_tax': '1.1',
#   'med_tax_morg_2016': '2381 ',
#   'med_tax_nomorg_2016': '2586 ',
#   'med_house_value_2016': '217875',
#   'med_house_income_2016': '62666',
#   'med_owner_cost_morg': '1414',
#   'med_owner_cost_nomorg': '500',
#   'med_rent_2016': '1125',
#   'med_asking_price_2016': '213839',
#   'unemployment': '5.0'}]

# %%
#Convert to dataframe

city_dataframe = pd.DataFrame(city_data)

# %%
#Check dataframe

city_dataframe
# Out:
#    zipcode population_2016 population_2010 population_2000  \
# 0    19102            4936            4705            4396
# 1    19103           23239           21908           19714
# 2    19104           55677           51808           50125
# 3    19106           12268           11740            8359
# 4    19107           13657           14875           12340
# 5    19111           70919           63090           58874
# 6    19114           31078           30907           31083
# 7    19115           33050           33207           31853
# 8    19116           33688           33112           32560
# 9    19118           10690            9808            9608
# 10   19119           29015           27035           28873
# 11   19120           77555           68104           68831
# 12   19121           33119           36572           34935
# 13   19122           22392           21653           19589
# 14   19123           15036           13416            9818
# 15   19124           70116           66691           63131
# 16   19125           24855           22958           23646
# 17   19126           15559           15758           16484
# 18   19127            6352            5913            5465
# 19   19128           37488           35239           36420
# 20   19129           11176           10975           10748
# 21   19130           27148           24870           22874
# 22   19131           42396           43172           47044
# 23   19132           35086           36268           41709
# 24   19133           27195           26063           27971
# 25   19134           65008           60675           57922
# 26   19135           32052           33091           30881
# 27   19136           34138           40647           40080
# 28   19137            8402            8638            8069
# 29   19138           34292           32273           34477
# 30   19139           44122           41271           43866
# 31   19140           51865           54133           57125
# 32   19141           34808           31376           34984
# 33   19142           28625           29595           29063
# 34   19143           64429           64849           71169
# 35   19144           41195           43329           46794
# 36   19145           48587           47261           45647
# 37   19146           37767           35113           35783
# 38   19147           39405           36228           32680
# 39   19148           54642           49732           48573
# 40   19149           57749           55006           48483
# 41   19150           24725           23378           25274
# 42   19151           34884           29883           31255
# 43   19152           35387           33293           31379
# 44   19153           12972           12259           12324
# 45   19154           33634           34196           35606
#
#    costofliving_index_2016 land_area_sqmi water_area_sqmi  \
# 0                    110.5            0.2             0.0
# 1                    112.3            0.6             0.0
# 2                    107.1            3.0             0.1
# 3                    109.6            0.8             0.4
# 4                    110.6            0.5             0.0
# 5                    104.9            4.8             0.0
# 6                    105.0            5.6             0.3
# 7                    106.8            5.6             0.1
# 8                    106.7            5.0             0.0
# 9                    110.8            3.2             0.0
# 10                   105.6            3.2             0.0
# 11                   103.4            3.4             0.0
# 12                   105.3            2.2             0.1
# 13                   105.3            1.3             0.0
# 14                   108.7            1.3             0.1
# 15                   103.8            4.9             0.0
# 16                   105.1            1.4             0.2
# 17                   105.0            1.1             0.0
# 18                   106.2            0.5             0.1
# 19                   106.1            7.1             0.1
# 20                   106.5            2.2             0.1
# 21                   108.2            1.3             0.1
# 22                   104.4            5.3             0.3
# 23                   101.8            2.2             0.0
# 24                   102.2            1.3             0.0
# 25                   103.2            3.5             0.3
# 26                   102.9            2.3             0.3
# 27                   103.8            4.6             0.9
# 28                   103.5            2.4             0.9
# 29                   103.9            1.7             0.0
# 30                   103.1            1.8             0.0
# 31                   102.9            3.1             0.0
# 32                   103.5            1.8             0.0
# 33                   103.2            1.7             0.0
# 34                   102.8            3.2             0.1
# 35                   105.0            3.4             0.0
# 36                   105.4            4.9             0.3
# 37                   107.1            1.7             0.1
# 38                   107.6            1.4             0.2
# 39                   105.1            4.2             0.6
# 40                   104.8            2.4             0.0
# 41                   105.0            1.5             0.0
# 42                   103.7            2.4             0.0
# 43                   105.0            2.8             0.0
# 44                   104.8            7.2             1.2
# 45                   104.9            6.3             0.1
#
#    population_dentisty_per_sqmi population_2016_male population_2016_female  \
# 0                         26137                 2504                   2432
# 1                         36367                10223                  13015
# 2                         18519                28105                  27571
# 3                         15180                 6230                   6037
# 4                         24867                 6736                   6920
# 5                         14679                34417                  36501
# 6                          5550                14983                  16094
# 7                          5887                15570                  17479
# 8                          6731                15874                  17813
# 9                          3351                 4758                   5931
# 10                         8964                13485                  15529
# 11                        22786                37283                  40271
# 12                        14978                14861                  18256
# 13                        17642                11119                  11273
# 14                        11896                 7189                   7846
# 15                        14383                32198                  37916
# 16                        18062                12794                  12061
# 17                        13615                 7091                   8467
# 18                        11557                 3504                   2848
# 19                         5306                18033                  19454
# 20                         5083                 5342                   5833
# 21                        20973                13871                  13277
# 22                         8034                18304                  24090
# 23                        16211                15985                  19099
# 24                        20909                12792                  14402
# 25                        18530                31568                  33439
# 26                        13765                15458                  16593
# 27                         7414                17383                  16755
# 28                         3490                 4271                   4131
# 29                        19903                14777                  19514
# 30                        24928                19121                  25000
# 31                        16992                24712                  27152
# 32                        19193                15674                  19133
# 33                        16978                13341                  15283
# 34                        20211                29447                  34980
# 35                        11999                18877                  22317
# 36                         9970                23182                  25403
# 37                        22353                17495                  20270
# 38                        27998                19454                  19950
# 39                        12939                27401                  27241
# 40                        23778                27813                  29935
# 41                        16400                10733                  13990
# 42                        14585                15160                  19722
# 43                        12554                17079                  18307
# 44                         1812                 6133                   6838
# 45                         5309                16401                  17232
#
#    property_tax med_tax_morg_2016 med_tax_nomorg_2016 med_house_value_2016  \
# 0           1.0             4331                4014                427870
# 1           0.9             5126                3242                521102
# 2           0.8             1781                 729                128194
# 3           0.9             3562                6231                497794
# 4           0.8             3092                3049                374150
# 5           1.1             2091                2207                188684
# 6           1.1             2288                2365                209884
# 7           1.1             2872                2915                261605
# 8           1.1             2746                2827                259274
# 9           1.0             5407                6147                538638
# 10          1.0             2665                2535                263492
# 11          1.2             1259                1250                107106
# 12          0.6              778                 437                 98005
# 13          0.6             1025                 897                170704
# 14          0.6             2143                1824                352174
# 15          1.1             1258                1067                108105
# 16          0.6             1297                 955                216987
# 17          1.0             1719                1531                155942
# 18          0.8             2448                1865                255057
# 19          1.0             2602                2590                260717
# 20          0.8             2016                1453                215544
# 21          0.9             3399                3301                381253
# 22          1.0             1431                1103                119759
# 23          0.9              544                 486                 53720
# 24          0.6              478                 281                 56272
# 25          1.0              952                 837                 90901
# 26          1.1             1405                1406                125087
# 27          1.1             1745                1759                165265
# 28          0.9             1410                1336                145287
# 29          1.1             1367                1257                120203
# 30          0.9              823                 745                 85907
# 31          0.9              664                 593                 68592
# 32          1.1             1209                1110                107328
# 33          1.2             1066                 957                 88016
# 34          0.9              920                 825                 92122
# 35          1.1             1453                1310                128638
# 36          0.8             1433                1344                174034
# 37          0.4             1613                 903                291129
# 38          0.7             2742                2077                357612
# 39          0.7             1435                1347                189572
# 40          1.1             1547                1534                141846
# 41          1.0             1855                1813                177252
# 42          1.0             1507                1178                140070
# 43          1.2             2499                2352                207109
# 44          1.1             1795                1414                152390
# 45          1.1             2381                2586                217875
#
#    med_house_income_2016 med_owner_cost_morg med_owner_cost_nomorg  \
# 0                 101898                3001                   978
# 1                  73681                2940                   795
# 2                  22676                1187                   413
# 3                 105334                2615                  1242
# 4                  52804                1830                   936
# 5                  46593                1364                   505
# 6                  56397                1486                   527
# 7                  49357                1675                   583
# 8                  48247                1629                   568
# 9                  82904                2601                   945
# 10                 59948                1600                   595
# 11                 36160                 999                   390
# 12                 19660                 918                   377
# 13                 34836                1060                   380
# 14                 60191                1802                   517
# 15                 31532                1038                   378
# 16                 54678                1313                   386
# 17                 36631                1368                   510
# 18                 73495                1851                   475
# 19                 66695                1640                   535
# 20                 49934                1448                   407
# 21                 74219                2002                   648
# 22                 32404                1106                   429
# 23                 23242                 785                   333
# 24                 18871                 855                   309
# 25                 29101                 875                   359
# 26                 43398                1070                   419
# 27                 48241                1191                   438
# 28                 52554                1135                   416
# 29                 37010                1077                   437
# 30                 27449                 873                   364
# 31                 22527                 759                   337
# 32                 30448                1064                   412
# 33                 31215                 933                   380
# 34                 32075                 957                   415
# 35                 29209                1136                   453
# 36                 39796                1196                   420
# 37                 54608                1803                   395
# 38                 72963                1694                   497
# 39                 48021                1275                   389
# 40                 41544                1141                   412
# 41                 45594                1220                   470
# 42                 46668                1189                   439
# 43                 51105                1430                   490
# 44                 42619                1326                   427
# 45                 62666                1414                   500
#
#    med_rent_2016 med_asking_price_2016 unemployment
# 0           2082               1081578          2.5
# 1           1601                362650          2.9
# 2            941                222828          7.0
# 3           1737                567543          2.5
# 4           1237                408260          5.4
# 5            945                173483          9.1
# 6           1068                177689          6.1
# 7            976                231775          4.9
# 8            931                203806          6.1
# 9           1468                846508          3.8
# 10          1000                306518          7.7
# 11           968                104071         14.5
# 12           750                112356         12.9
# 13           776                198075          9.9
# 14          1210                344502          7.9
# 15           903                136644         15.2
# 16          1022                184084          9.6
# 17           914                181244         11.5
# 18          1406                222828          2.2
# 19          1245                191853          4.4
# 20          1207               5954300          7.1
# 21          1328                280069          3.9
# 22           954                112123          9.2
# 23           815                222828         13.5
# 24           693                222828         18.5
# 25           876                222828         17.0
# 26           884                118464          9.0
# 27           900                180934          7.5
# 28          1030                110094         10.2
# 29           977                107782         13.8
# 30           855                222828         13.3
# 31           829                222828         19.5
# 32           819                130657         14.3
# 33           964                222828         13.4
# 34           854                222828         14.5
# 35           866                195486         11.2
# 36           954                214731          9.6
# 37          1039                269196          6.7
# 38          1255                395531          4.8
# 39          1023                213936          8.7
# 40          1114                137090          9.7
# 41          1028                162697         11.2
# 42          1008                140326          8.8
# 43           978                203658          6.2
# 44          1078                190050          9.0
# 45          1125                213839          5.0

# %%
#Pickle zipcode dataframe

with open('philly_zipcodes_dataframe', 'wb') as philly_zipcodes_dataframe:
    pickle.dump(city_dataframe, philly_zipcodes_dataframe)
